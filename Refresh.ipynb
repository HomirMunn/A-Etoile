# %% [markdown]
# <h1 style="color:#5A8E00; font-weight: bold;">
# Algorithme A\*
# </h1>
# <br>Nous allons de ce pas nous immerger dans une application de l'algorithme A\*. Le but du script qui suit va être de déterminer les affectations qui minimisent le coût total d'un opération à partir d'un tableau à 2 dimensions dans lequel sont représentés les-dits coûts.

# %% [markdown]
# On importe numpy pour réaliser des opérations plus vite que l'éclair, pandas pour afficher les résultats de manière élégante et heapq qui n'est autre qu'une implémentation des Tas (qui vont nous permettre de gagner un peu / pas mal de temps de calcul). Un petit coup d'oeil sur la documentation de heapq et notamment des fonctions <b style="color:#DB5B30">heappush</b> et <b style="color:#DB5B30">heappop</b> ne fait pas de mal : https://docs.python.org/3/library/heapq.html

# %%
import numpy as np
import pandas as pd
from heapq import heappush, heappop

# %% [markdown]
# La classe Noeud ci-dessous représente une bonne partie de l'algorithme et mérite quelques éclaircissements. Nous vons invitons tout d'abord à jeter un oeil à la classe afin d'en notifier les principales attributs et fonctions.
#
# <u style="color:#5A8E00; font-size:16px">Attributs :</u>
# * <b style="color:#DB5B30">n :</b> La profondeur maximale du graphe. Si le tableau de coûts est de dimensions m\*m alors n=m
# * <b style="color:#DB5B30">g :</b> Le coût d'un chemin optimal du premier noeud à celui-ci (du noeud de profondeur 0 au noeud de profondeur p)
# * <b style="color:#DB5B30">p :</b> La profondeur du noeud, c'est à dire le nombre d'ancêtres que possède ce noeud. Par exemple le premier noeud est de profondeur 0, et un noeud but est de profondeur n.
# * <b style="color:#DB5B30">affectations :</b> Une liste contenant toutes les affectations "qui sont faîtes" pour ce noeud. Pour un noeud but on a une liste d'affectations complète qui décrira une situation d'allocations finie. Notre algorithme devant se terminer toujours par des affectations optimales, le dernier noeud choisi possèdera donc la liste des allocations optimales.
# * <b style="color:#DB5B30">h :</b> L'heuristique du noeud. C'est une estimation du coût chemin optimal de ce noeud (de profondeur p) à un but (de profondeur n). Comme nous voulons trouver le chemin optimal de 0 à n, nous devons respecter la propriété $h(p) \leq h*(p)$ où h*(p) est le coût du chemin optimal de ce noeud à un but.
# * <b style="color:#DB5B30">f :</b> Estimation du coût d'un chemin optimal de 0 à un but en passant par ce noeud. C'est donc ce paramètre là que l'on cherche à minimiser. Quand l'algorithme se termine, on veut que le noeud but sur lequel il se termine soit celui avec le plus petit f possible. Ce paramètre va donc nous servir à ordonner les noeuds.
#
# <u style="color:#5A8E00; font-size:16px">Fonctions :</u>
# * <b style="color:#DB5B30">n :</b> La profondeur maximale du graphe. Si le tableau de coûts est de dimensions m\*m alors n=m
# * <b style="color:#DB5B30">g :</b> Le coût d'un chemin optimal du premier noeud à celui-ci (du noeud de profondeur 0 au noeud de profondeur p)

# %%
class Noeud:
    def __init__(self, n, couts, g=0, p=0, affectations=list()):
        self.n = n
        self.g = g
        self.p = p
        self.affectations = affectations
        self.h = self.calculer_h(couts)
        self.f = self.g + self.h
    
    def estBut(self):
        return self.p == self.n
    
    def calculer_h(self, couts):
        if self.estBut():
            return 0
        temp = np.delete(couts[self.p:], self.affectations, 1)
        return max(np.amin(temp, 1).sum(), np.amin(temp, 0).sum())
    
    def developpe(self, couts):
        heritiers = list()
        for i, cout in enumerate(couts[self.p]):
            if i not in self.affectations:
                heritiers.append(Noeud(self.n, couts, g=self.g+cout, p=self.p+1, affectations=self.affectations+[i]))
        return heritiers
    
    def __lt__(self, other):
        return self.f < other.f

# %%
couts = np.random.randint(1000, size=(15, 15))

n = len(couts)
OUVERT = [Noeud(n, couts)]

while len(OUVERT) > 0:
    noeud = heappop(OUVERT)
    if noeud.estBut():
        break
    for heritier in noeud.developpe(couts):
        heappush(OUVERT, heritier)
# Out:
# 234 ms ± 44.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
def print_affectations(couts, affectations):
    df = pd.DataFrame(couts)
    return df.style.apply(lambda tab: color_couts(affectations), axis=None)

def color_couts(affectations):
    n = len(affectations)
    ar = [['']*n for i in range(n)]
    for i, j in enumerate(affectations):
        ar[i][j] = 'background-color: #FFC900'
    return pd.DataFrame(ar)

# %%
print_affectations(couts, noeud.affectations)
# Out:
# <style  type="text/css" >
#     #T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col1 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col5 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col10 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row3_col3 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row4_col9 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row5_col7 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row6_col14 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row7_col13 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row8_col2 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row9_col4 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row10_col6 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row11_col12 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row12_col0 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row13_col11 {
#             background-color:  #FFC900;
#         }    #T_24a7dc7a_32cc_11e8_a522_6045cb218280row14_col8 {
#             background-color:  #FFC900;
#         }</style>
# <table id="T_24a7dc7a_32cc_11e8_a522_6045cb218280" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_24a7dc7a_32cc_11e8_a522_6045cb218280level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col0" class="data row0 col0" >856</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col1" class="data row0 col1" >61</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col2" class="data row0 col2" >750</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col3" class="data row0 col3" >290</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col4" class="data row0 col4" >546</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col5" class="data row0 col5" >961</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col6" class="data row0 col6" >58</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col7" class="data row0 col7" >725</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col8" class="data row0 col8" >107</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col9" class="data row0 col9" >190</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col10" class="data row0 col10" >82</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col11" class="data row0 col11" >731</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col12" class="data row0 col12" >923</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col13" class="data row0 col13" >127</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row0_col14" class="data row0 col14" >381</td>
#     </tr>    <tr>
#         <th id="T_24a7dc7a_32cc_11e8_a522_6045cb218280level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col0" class="data row1 col0" >785</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col1" class="data row1 col1" >540</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col2" class="data row1 col2" >782</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col3" class="data row1 col3" >691</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col4" class="data row1 col4" >419</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col5" class="data row1 col5" >164</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col6" class="data row1 col6" >722</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col7" class="data row1 col7" >806</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col8" class="data row1 col8" >964</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col9" class="data row1 col9" >373</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col10" class="data row1 col10" >610</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col11" class="data row1 col11" >131</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col12" class="data row1 col12" >603</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col13" class="data row1 col13" >873</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row1_col14" class="data row1 col14" >552</td>
#     </tr>    <tr>
#         <th id="T_24a7dc7a_32cc_11e8_a522_6045cb218280level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col0" class="data row2 col0" >935</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col1" class="data row2 col1" >623</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col2" class="data row2 col2" >878</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col3" class="data row2 col3" >248</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col4" class="data row2 col4" >480</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col5" class="data row2 col5" >738</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col6" class="data row2 col6" >655</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col7" class="data row2 col7" >481</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col8" class="data row2 col8" >672</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col9" class="data row2 col9" >538</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col10" class="data row2 col10" >18</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col11" class="data row2 col11" >508</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col12" class="data row2 col12" >741</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col13" class="data row2 col13" >562</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row2_col14" class="data row2 col14" >328</td>
#     </tr>    <tr>
#         <th id="T_24a7dc7a_32cc_11e8_a522_6045cb218280level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row3_col0" class="data row3 col0" >779</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row3_col1" class="data row3 col1" >754</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row3_col2" class="data row3 col2" >638</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row3_col3" class="data row3 col3" >194</td>
#         <td id="T_24a7dc7a_32cc_11e8_a522_6045cb218280row3_col4" class="da

# %% [markdown]
# <table style="float:left; font-family:'Arial'">
#   <tr style="background-color:white">
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#   </tr>
#   <tr style="background-color:white">
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#   </tr>
#   <tr style="background-color:white">
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#   </tr>
#   <tr style="background-color:white">
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#     <td style="border: 1px solid black; border-collapse: collapse; width:30px; height:30px; text-align:center;">1</td>
#   </tr>
# </table>
